# %%
import pandas as pd
import time
no_loads = pd.read_excel("No_Loads.xlsx")
filter_funds = no_loads[no_loads['Fund Family Name'] == 'Fidelity Investments']
filter_funds['Ticker']
no_loads.head()

# %%
# Import yfinance
import yfinance as yf  
 
# Get the data for the stock Apple by specifying the stock ticker, start date, and end date
data = yf.download('FTIWX','2000-01-01','2019-09-27')
 
# Plot the close prices
import matplotlib.pyplot as plt
data.Close.plot()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 downloaded

# %% [markdown]
# ## Sample Methods

# %%
ticker = yf.Ticker("FTIWX")
# get stock info
ticker.info

# get historical market data
hist = ticker.history(period="max")
hist.head()

# # show actions (dividends, splits)
# ticker.actions

# # show dividends
# ticker.dividends

# # show splits
# ticker.splits

# # show financials
# ticker.financials

# # show balance heet
# ticker.balance_sheet

# # show cashflow
# ticker.cashflow

# # show options expirations
# ticker.options

# # get option chain for specific expiration
# opt = msft.option_chain('YYYY-MM-DD')
# # data available via: opt.calls, opt.puts
# Out:
#                 Open      High       Low     Close  Volume  Dividends  \
# Date
# 2005-09-01  7.580736  7.580736  7.580736  7.580736       0       0.00
# 2005-09-02  7.574855  7.574855  7.574855  7.574855       0       0.03
# 2005-09-06  7.598380  7.598380  7.598380  7.598380       0       0.00
# 2005-09-07  7.598380  7.598380  7.598380  7.598380       0       0.00
# 2005-09-08  7.598380  7.598380  7.598380  7.598380       0       0.00
#
#             Stock Splits
# Date
# 2005-09-01             0
# 2005-09-02             0
# 2005-09-06             0
# 2005-09-07             0
# 2005-09-08             0

# %%
hist[['Open','High','Low','Close']].head()
# Out:
#                 Open      High       Low     Close
# Date
# 2005-09-01  7.580736  7.580736  7.580736  7.580736
# 2005-09-02  7.574855  7.574855  7.574855  7.574855
# 2005-09-06  7.598380  7.598380  7.598380  7.598380
# 2005-09-07  7.598380  7.598380  7.598380  7.598380
# 2005-09-08  7.598380  7.598380  7.598380  7.598380

# %%
fidelity = filter_funds['Ticker']
type(filter_funds)
# Out:
# pandas.core.frame.DataFrame

# %%
filter_funds = no_loads[no_loads['Fund Family Name'] == 'Fidelity Investments']
filter_funds
# Out:
#                                      Fund Name      Fund Family Name Ticker  \
# 3250     Fidelity Advisor Asset Manager® 20% I  Fidelity Investments  FTIWX
# 3251     Fidelity Advisor Asset Manager® 30% I  Fidelity Investments  FTINX
# 3252     Fidelity Advisor Asset Manager® 40% I  Fidelity Investments  FFNIX
# 3253     Fidelity Advisor Asset Manager® 50% I  Fidelity Investments  FFIMX
# 3254     Fidelity Advisor Asset Manager® 60% I  Fidelity Investments  FSNIX
# 3255     Fidelity Advisor Asset Manager® 70% I  Fidelity Investments  FAAIX
# 3256     Fidelity Advisor Asset Manager® 85% I  Fidelity Investments  FEYIX
# 3257          Fidelity Advisor Freedom® 2005 I  Fidelity Investments  FFIVX
# 3258          Fidelity Advisor Freedom® 2010 I  Fidelity Investments  FCIFX
# 3259          Fidelity Advisor Freedom® 2015 I  Fidelity Investments  FFVIX
# 3260          Fidelity Advisor Freedom® 2020 I  Fidelity Investments  FDIFX
# ...

# %%
time.sleep(5); print("hi")
# Out:
# hi

# %%
yf.Ticker('FTIWX').info
# Out:
# {'language': 'en-US',
#  'region': 'US',
#  'quoteType': 'MUTUALFUND',
#  'currency': 'USD',
#  'regularMarketPrice': 13.53,
#  'regularMarketTime': 1569888013,
#  'regularMarketChange': 0.02,
#  'shortName': 'Fidelity Advisor Asset Manager ',
#  'fiftyDayAverageChangePercent': 0.0018729994,
#  'twoHundredDayAverage': 13.344058,
#  'twoHundredDayAverageChange': 0.1859417,
#  'twoHundredDayAverageChangePercent': 0.013934419,
#  'sourceInterval': 15,
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'gmtOffSetMilliseconds': -14400000,
#  'esgPopulated': False,
#  'tradeable': False,
#  'triggerable': False,
#  'exchange': 'NAS',
#  'market': 'us_market',
#  'priceHint': 2,
#  'regularMarketChangePercent': 0.14803849,
#  'regularMarketPreviousClose': 13.509999,
#  'messageBoardId': 'finmb_28958406',
#  'fullExchangeName': 'Nasdaq',
#  'longName': 'Fidelity Advisor Asset Manager 20% Fund I Class',
#  'exchangeDataDelayedBy': 0,
# ...

# %%
results = []
i_start = 0 
for tickername in list(filter_funds['Ticker'])[0:2]:
    for f in tickername:
        try:
            data = yf.download(tickers=f, period='max', interval='3mo', group_by='ticker')
            results.append(data)
            results_df = results[0]
        except:
            pass
        print(len(results))
        for dFrame in results[1:]:
            results_df = pd.concat([results_df,dFrame])
# Out:
# [*********************100%***********************]  1 of 1 downloaded
# 1
# [*********************100%***********************]  1 of 1 downloaded
# 2
# [*********************100%***********************]  1 of 1 downloaded
# 3
# [*********************100%***********************]  1 of 1 downloaded
# 4
# [*********************100%***********************]  1 of 1 downloaded
# 5
# [*********************100%***********************]  1 of 1 downloaded
# 6
# [*********************100%***********************]  1 of 1 downloaded
# 7
# [*********************100%***********************]  1 of 1 downloaded
# 8
# [*********************100%***********************]  1 of 1 downloaded
# 9
# Exception in thread Thread-203:
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\yfinance\__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
# ...

# %%
results_new = results_new.sort_values("Date")

# %%
results_new.index
# Out:
# DatetimeIndex(['1972-06-01', '1972-07-25', '1972-09-01', '1972-10-25',
#                '1972-12-01', '1973-01-23', '1973-03-01', '1973-04-24',
#                '1973-06-01', '1973-07-24',
#                ...
#                '2019-07-09', '2019-07-22', '2019-08-01', '2019-08-13',
#                '2019-09-01', '2019-09-30', '2019-09-30', '2019-09-30',
#                '2019-09-30', '2019-09-30'],
#               dtype='datetime64[ns]', name='Date', length=932, freq=None)

# %%
results_new = results_new.sort_values("Date")

# %%
loop = pd.DataFrame(results[0])
index = loop.index.strftime('%B %d, %Y, %r')
x = pd.DataFrame(data=loop,index=index)
resultsDF = results[0].reset_index()

# %%
resultsDF
# Out:
#           Date   Open   High    Low  Close  Adj Close  Volume
# 0   2005-09-01  12.92  13.10  12.72  13.02       7.64     0.0
# 1   2005-09-02    NaN    NaN    NaN    NaN        NaN     NaN
# 2   2005-10-07    NaN    NaN    NaN    NaN        NaN     NaN
# 3   2005-11-04    NaN    NaN    NaN    NaN        NaN     NaN
# 4   2005-12-01  13.08  13.13  12.74  13.06       7.72     0.0
# 5   2005-12-02    NaN    NaN    NaN    NaN        NaN     NaN
# 6   2006-02-03    NaN    NaN    NaN    NaN        NaN     NaN
# 7   2006-03-01  13.11  13.16  12.88  12.91       7.69     0.0
# 8   2006-03-03    NaN    NaN    NaN    NaN        NaN     NaN
# 9   2006-04-07    NaN    NaN    NaN    NaN        NaN     NaN
# 10  2006-05-05    NaN    NaN    NaN    NaN        NaN     NaN
# 11  2006-06-01  12.95  13.06  12.75  13.06       7.84     0.0
# 12  2006-06-02    NaN    NaN    NaN    NaN        NaN     NaN
# 13  2006-07-07    NaN    NaN    NaN    NaN        NaN     NaN
# ...

# %%
iDF = filter_funds
iDF['Date'] = resultsDF['Date']
iDF['Open'] = resultsDF['Open']
iDF['High'] = resultsDF['High']
iDF['Low'] = resultsDF['Low']
iDF['Adj Close'] = resultsDF['Adj Close']
iDF['Close'] = resultsDF['Close']
iDF['Volume'] = resultsDF['Volume']
iDF
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
bigdata = filter_funds.merge(resultsDF, sort =False)
bigdata
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-194-06cdf035e0f1> in <module>
# ----> 1 bigdata = filter_funds.merge(resultsDF, sort =False)
#       2 bigdata
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6866                      right_on=right_on, left_index=left_index,
#    6867                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6868                      copy=copy, indicator=indicator, validate=validate)
#    6869
#    6870     def round(self, decimals=0, *args, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...
